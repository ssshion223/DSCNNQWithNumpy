# %%
import numpy as np
import model
from PIL import Image

# %%
pgm = Image.open("samples/yes_sample_features_int8.pgm")
input = np.array(pgm).reshape(1, 49, 10, 1)
model = model.model()
output = model.prediction(input)
print(output)
# Out:
# [[  0 105 216  91  43  90 115  95  70 105  98 118]]
