# %%
import numpy as np
import model
from PIL import Image

# %%
# weight = np.load("weights/DS-CNN_conv_1_weights_quant_FakeQuantWithMinMaxVars.npy")
# print(weight[0, :, :, 0])

# %%
# input = np.ones((1, 49, 10, 1))
pgm = Image.open("samples/yes_sample_features_int8.pgm")
input = np.array(pgm).reshape(1, 49, 10, 1)
# print(input)
model = model.model()
output = model.prediction(input)
print(output)
# Out:
# (25, 5, 10, 4)
# [[  0  82  83  30  77  13 100  49  81 122  97 112]]
